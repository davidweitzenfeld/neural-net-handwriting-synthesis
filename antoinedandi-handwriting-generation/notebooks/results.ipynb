# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke

# %% [markdown]
# This is what you should modify:

# %%
from experiments import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='hello world ! ')
plot_stroke(stroke)

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print(text)
# Out:
# ...
# hello world I I I I
